# %%
import cv2
cv2.__version__
# Out:
# '4.8.1'

# %%
img = cv2.imread("bird.jpeg")

# %%
import matplotlib.pyplot as plt

plt.imshow(img) # the plotted image will be different from actual image
# this is bcoz, opencv reads image in BGR mode, while, matplotlib imshow expects RGB image.
